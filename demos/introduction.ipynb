# %% [markdown]
# # Intro to Developmental Interpretability
#
# Developmental interpretability ("devinterp") studies how structure develops over the course of training.
#
# In particular, our aim is to develop tools for detecting, understanding, and preventing dangerous transitions during training — to capabilities, values, behaviors.

# %% [markdown]
# ## Set-up

# %%
# !pip install devinterp transformers
# Out:
# Requirement already satisfied: devinterp in /Users/Jesse/Projects/devinterp (0.0.0)
# Requirement already satisfied: transformers in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (4.30.2)
# Requirement already satisfied: accelerate==0.20.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.20.3)
# Requirement already satisfied: aiohttp==3.8.4 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.8.4)
# Requirement already satisfied: aiosignal==1.3.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.3.1)
# Requirement already satisfied: annotated-types==0.5.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.5.0)
# Requirement already satisfied: appdirs==1.4.4 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.4.4)
# Requirement already satisfied: appnope==0.1.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.1.3)
# Requirement already satisfied: asttokens==2.2.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2.2.1)
# Requirement already satisfied: async-timeout==4.0.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (4.0.2)
# Requirement already satisfied: attrs==23.1.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (23.1.0)
# Requirement already satisfied: backcall==0.2.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.2.0)
# Requirement already satisfied: boto3==1.28.25 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.28.25)
# Requirement already satisfied: botocore==1.31.25 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.31.25)
# Requirement already satisfied: certifi==2023.5.7 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2023.5.7)
# Requirement already satisfied: charset-normalizer==3.2.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.2.0)
# Requirement already satisfied: click==8.1.4 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (8.1.4)
# Requirement already satisfied: comm==0.1.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.1.3)
# Requirement already satisfied: contourpy==1.1.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.1.0)
# Requirement already satisfied: cycler==0.11.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.11.0)
# Requirement already satisfied: datasets==2.13.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2.13.1)
# Requirement already satisfied: debugpy==1.6.7 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.6.7)
# Requirement already satisfied: decorator==5.1.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (5.1.1)
# Requirement already satisfied: dill==0.3.6 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.3.6)
# Requirement already satisfied: docker-pycreds==0.4.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.4.0)
# Requirement already satisfied: einops==0.6.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.6.1)
# Requirement already satisfied: executing==1.2.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.2.0)
# Requirement already satisfied: fancy-einsum==0.0.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.0.3)
# Collecting filelock==3.12.2
#   Using cached filelock-3.12.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: fonttools==4.41.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (4.41.0)
# Requirement already satisfied: frozenlist==1.3.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.3.3)
# Requirement already satisfied: fsspec==2023.6.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2023.6.0)
# Requirement already satisfied: gitdb==4.0.10 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (4.0.10)
# Requirement already satisfied: GitPython==3.1.32 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.1.32)
# Requirement already satisfied: huggingface-hub==0.16.4 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.16.4)
# Requirement already satisfied: idna==3.4 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.4)
# Requirement already satisfied: ipykernel==6.24.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (6.24.0)
# Requirement already satisfied: ipython==8.14.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (8.14.0)
# Requirement already satisfied: ipywidgets==8.0.7 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (8.0.7)
# Requirement already satisfied: jedi==0.18.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.1.2)
# Requirement already satisfied: jmespath==1.0.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.0.1)
# Requirement already satisfied: jupyter_client==8.3.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (8.3.0)
# Requirement already satisfied: jupyter_core==5.3.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (5.3.1)
# Requirement already satisfied: jupyterlab-widgets==3.0.8 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.0.8)
# Requirement already satisfied: kiwisolver==1.4.4 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.4.4)
# Requirement already satisfied: markdown-it-py==3.0.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2.1.3)
# Requirement already satisfied: matplotlib==3.7.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.1.6)
# Requirement already satisfied: mdurl==0.1.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.1.2)
# Requirement already satisfied: mpmath==1.3.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.3.0)
# Requirement already satisfied: multidict==6.0.4 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (6.0.4)
# Requirement already satisfied: multiprocess==0.70.14 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.70.14)
# Requirement already satisfied: nest-asyncio==1.5.6 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.5.6)
# Requirement already satisfied: networkx==3.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.1)
# Requirement already satisfied: numpy==1.25.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.25.1)
# Requirement already satisfied: packaging==23.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (23.1)
# Requirement already satisfied: pandas==2.0.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2.0.3)
# Requirement already satisfied: parso==0.8.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.8.3)
# Requirement already satisfied: pathtools==0.1.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.1.2)
# Requirement already satisfied: pexpect==4.8.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.7.5)
# Requirement already satisfied: Pillow==10.0.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (10.0.0)
# Requirement already satisfied: platformdirs==3.8.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.8.1)
# Requirement already satisfied: prompt-toolkit==3.0.39 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.0.39)
# Requirement already satisfied: protobuf==4.23.4 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (4.23.4)
# Requirement already satisfied: psutil==5.9.5 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (5.9.5)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.2.2)
# Requirement already satisfied: pyarrow==12.0.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (12.0.1)
# Requirement already satisfied: pydantic in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2.3.0)
# Requirement already satisfied: pydantic_core in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2.6.3)
# Requirement already satisfied: Pygments==2.15.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2.15.1)
# Requirement already satisfied: pyparsing==3.0.9 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2.8.2)
# Requirement already satisfied: python-dotenv==1.0.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.0.0)
# Requirement already satisfied: pytz==2023.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2023.3)
# Requirement already satisfied: PyYAML==6.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (6.0)
# Requirement already satisfied: pyzmq==25.1.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (25.1.0)
# Requirement already satisfied: regex==2023.6.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2023.6.3)
# Requirement already satisfied: requests==2.31.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2.31.0)
# Requirement already satisfied: rich==13.4.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (13.4.2)
# Requirement already satisfied: s3transfer==0.6.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.6.1)
# Requirement already satisfied: safetensors==0.3.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.3.1)
# Requirement already satisfied: sentry-sdk==1.28.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.28.0)
# Requirement already satisfied: setproctitle==1.3.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.3.2)
# Requirement already satisfied: six==1.16.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.16.0)
# Requirement already satisfied: smmap==5.0.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (5.0.0)
# Requirement already satisfied: stack-data==0.6.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.6.2)
# Requirement already satisfied: sympy==1.12 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.12)
# Requirement already satisfied: tokenizers==0.13.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.13.3)
# Requirement already satisfied: torch==2.0.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2.0.1)
# Requirement already satisfied: torchtyping==0.1.4 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.1.4)
# Requirement already satisfied: torchvision==0.15.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.15.2)
# Requirement already satisfied: tornado==6.3.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (6.3.2)
# Requirement already satisfied: tqdm==4.65.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (4.65.0)
# Requirement already satisfied: traitlets==5.9.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (5.9.0)
# Requirement already satisfied: typing_extensions==4.7.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (4.7.1)
# Requirement already satisfied: tzdata==2023.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (2023.3)
# Requirement already satisfied: urllib3==1.26.16 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.26.16)
# Requirement already satisfied: wandb==0.15.5 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.15.5)
# Requirement already satisfied: wcwidth==0.2.6 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (0.2.6)
# Requirement already satisfied: widgetsnbextension==4.0.8 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (4.0.8)
# Requirement already satisfied: xxhash==3.2.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (3.2.0)
# Requirement already satisfied: yarl==1.9.2 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from devinterp) (1.9.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from jupyter_client==8.3.0->devinterp) (6.8.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from matplotlib==3.7.2->devinterp) (6.0.1)
# Requirement already satisfied: typeguard>=2.11.1 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from torchtyping==0.1.4->devinterp) (4.1.3)
# Requirement already satisfied: setuptools in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from wandb==0.15.5->devinterp) (58.1.0)
# Requirement already satisfied: zipp>=0.5 in /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter_client==8.3.0->devinterp) (3.16.2)
# Installing collected packages: filelock
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.12.3
#     Uninstalling filelock-3.12.3:
#       Successfully uninstalled filelock-3.12.3
# Successfully installed filelock-3.12.2
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/Jesse/Projects/devinterp/.venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# # Methods
#
# ## Local Learning Coefficients
#
# The first method we have have online is local learning coefficient estimation ([Lau et al. 2023](https://arxiv.org/abs/2308.12108)).
#
# For an in-depth explaination, see [this post](https://www.lesswrong.com/posts/6g8cAftfQufLmFDYT/you-re-counting-your-parameters-wrong). The short version is that:
# - The (local) learning coefficient $\hat\lambda$ is the "correct" measure of model complexity. Besides the loss, it's the most principled high-level way to compare models.
# - We can cheaply estimate the learning coefficient associated to a choice of weights $\hat w^*$ by using the following formula:
#
# $$
# \hat\lambda(\hat w^*)=\frac{\mathbb{E}_{w|\hat w^*, \gamma}^{\beta^*}\left[n L_n(w)\right] - n L_n(\hat w^*)}{\log n}.
# $$
#
# where, $n$ is the number of (training) samples, $L_n(w)$ is the negative log likelihood (i.e., your objective function), and $\mathbb{E}_w^{\beta^*}\left[n L_n(w)\right]$ is a "local average" of $nL_n(w)$ over a neighborhood of $\hat w^*$. The parameters $\gamma$ and $\beta^*$ control the local averaging.
#
# The difficulty is in performing the local average: we need to sample enough points and they need to be both diverse / spread out enough and close enough to the starting weight. To make sure they're spread out enough we use an optimizer like Stochastic Gradient Langevin Dynamics (SGLD), which is SGD plus Gaussian noise.

# %%
import torch
import torchvision
from transformers import AutoModelForImageClassification, AutoTokenizer
from torch import nn
from torch.nn import functional as F

from devinterp.slt import estimate_learning_coeff_with_summary, plot_learning_coeff_trace
from devinterp.optim import SGLD, SGNHT

# Load a pretrained MNIST classifier 
model = AutoModelForImageClassification.from_pretrained("fxmarty/resnet-tiny-mnist")
data = torchvision.datasets.MNIST(root="../data", download=True, transform=torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
]))
loader = torch.utils.data.DataLoader(data, batch_size=256, shuffle=True)

def criterion(inputs, outputs):
    print(F.cross_entropy(inputs.logits, outputs))
    return F.cross_entropy(inputs.logits, outputs)  # transformers doesn't output a vector

learning_coeff_stats = estimate_learning_coeff_with_summary(
    model, 
    loader=loader, 
    criterion=criterion,
    sampling_method=SGLD,
    optimizer_kwargs=dict(lr=1e-7, elasticity=10.),
    num_chains=10,  # How many independent chains to run
    num_draws=10,  # How many samples to draw per chain
    num_burnin_steps=0,  # How many samples to discard at the beginning of each chain
    num_steps_bw_draws=1,  # How many steps to take between each sample
)

print(learning_coeff_stats)
plot_learning_coeff_trace(learning_coeff_stats["trace"])
# Out:
# Chain 0:  10%|█         | 1/10 [00:00<00:00,  9.30it/s]
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[-2.2454, -1.5119, -1.5940,  ..., -2.0960, -1.6442, -0.7734],
#         [ 6.5746, -3.0550, -1.2515,  ..., -2.5544, -2.8164, -2.2505],
#         [-1.2790, -2.6840, -2.2942,  ..., -2.1974, -1.5519, -2.0668],
#         ...,
#         [-0.3131, -3.9972, -2.9814,  ..., -3.7111,  1.0519, -1.5244],
#         [-1.1514,  6.9047, -1.8375,  ..., -0.0598, -1.4345, -2.1385],
#         [-4.5053, -2.9693, -0.9873,  ..., -3.6877,  8.3504, -2.5258]],
#        grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# Chain 0:  40%|████      | 4/10 [00:00<00:00,  9.42it/s]
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# Chain 0:  60%|██████    | 6/10 [00:00<00:00,  9.39it/s]
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# Chain 0:  80%|████████  | 8/10 [00:00<00:00,  9.55it/s]
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# Chain 0: 100%|██████████| 10/10 [00:01<00:00,  9.56it/s]
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# Chain 1:  20%|██        | 2/10 [00:00<00:00, 10.47it/s]
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[-4.6761, -2.8588, -2.0046,  ..., -3.9824,  8.1989, -1.9930],
#         [-2.3280, -2.0914, -2.6055,  ..., -2.1801, -0.6119, -1.6876],
#         [-2.1476, -4.3063, -2.1165,  ..., -0.0836, -1.6033,  5.9487],
#         ...,
#         [ 6.9788, -3.2766, -2.0077,  ..., -2.7138, -2.5648, -1.7547],
#         [-2.0100, -1.8982, -1.6245,  ..., -2.4578, -0.7389, -1.6169],
#         [-2.4280, -2.3700, -0.8869,  ..., -2.1403, -0.5224, -0.4893]],
#        grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# Chain 1:  40%|████      | 4/10 [00:00<00:00, 10.54it/s]
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# Chain 1:  70%|███████   | 7/10 [00:00<00:00,  9.42it/s]
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>), hidden_states=None)
# Chain 1:  90%|█████████ | 9/10 [00:00<00:00,  9.60it/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:21                                                                                   │
# │                                                                                                  │
# │   18 │   print(inputs)                                                                           │
# │   19 │   return F.cross_entropy(inputs.logits, outputs)  # transformers doesn't output a vect    │
# │   20                                                                                             │
# │ ❱ 21 learning_coeff_stats = estimate_learning_coeff_with_summary(                                │
# │   22 │   model,                                                                                  │
# │   23 │   loader=loader,                                                                          │
# │   24 │   criterion=criterion,                                                                    │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/devinterp/slt/learning_coeff.py:72 in                            │
# │ estimate_learning_coeff_with_summary                                                             │
# │                                                                                                  │
# │    69 │   device: torch.device = torch.device("cpu"),                                            │
# │    70 │   verbose: bool = True,                                                                  │
# │    71 ) -> dict:                                                                                 │
# │ ❱  72 │   trace = sample(                                                                        │
# │    73 │   │   model=model,                                                                       │
# │    74 │   │   loader=loader,                                                                     │
# │    75 │   │   criterion=criterion,                                                               │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/devinterp/slt/sampler.py:164 in sample                           │
# │                                                                                                  │
# │   161 │   │   │   raise NotImplementedError("Cannot currently use multiprocessing with GPU")     │
# │   162 │   else:                                                                                  │
# │   163 │   │   for i in range(num_chains):                                                        │
# │ ❱ 164 │   │   │   results.append(_sample_single_chain(get_args(i)))                              │
# │   165 │                                                                                          │
# │   166 │   results_df = pd.concat(results, ignore_index=True)                                     │
# │   167 │   return results_df                                                                      │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/devinterp/slt/sampler.py:83 in _sample_single_chain              │
# │                                                                                                  │
# │    80                                                                                            │
# │    81                                                                                            │
# │    82 def _sample_single_chain(kwargs):                                                          │
# │ ❱  83 │   return sample_single_chain(**kwargs)                                                   │
# │    84                                                                                            │
# │    85                                                                                            │
# │    86 def sample(                                                                                │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/devinterp/slt/sampler.py:63 in sample_single_chain               │
# │                                                                                                  │
# │    60 │   for i, (xs, ys) in iterator:                                                           │
# │    61 │   │   optimizer.zero_grad()                                                              │
# │    62 │   │   xs, ys = xs.to(device), ys.to(device)                                              │
# │ ❱  63 │   │   y_preds = model(xs)                                                                │
# │    64 │   │   loss = criterion(y_preds, ys)                                                      │
# │    65 │   │                                                                                      │
# │    66 │   │   loss.backward()                                                                    │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:150 │
# │ 1 in _call_impl                                                                                  │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/transformers/models/resnet/mod │
# │ eling_resnet.py:390 in forward                                                                   │
# │                                                                                                  │
# │   387 │   │   """                                                                                │
# │   388 │   │   return_dict = return_dict if return_dict is not None else self.config.use_return   │
# │   389 │   │                                                                                      │
# │ ❱ 390 │   │   outputs = self.resnet(pixel_values, output_hidden_states=output_hidden_states, r   │
# │   391 │   │                                                                                      │
# │   392 │   │   pooled_output = outputs.pooler_output if return_dict else outputs[1]               │
# │   393                                                                                            │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:150 │
# │ 1 in _call_impl                                                                                  │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/transformers/models/resnet/mod │
# │ eling_resnet.py:329 in forward                                                                   │
# │                                                                                                  │
# │   326 │   │   )                                                                                  │
# │   327 │   │   return_dict = return_dict if return_dict is not None else self.config.use_return   │
# │   328 │   │                                                                                      │
# │ ❱ 329 │   │   embedding_output = self.embedder(pixel_values)                                     │
# │   330 │   │                                                                                      │
# │   331 │   │   encoder_outputs = self.encoder(                                                    │
# │   332 │   │   │   embedding_output, output_hidden_states=output_hidden_states, return_dict=ret   │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:150 │
# │ 1 in _call_impl                                                                                  │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/transformers/models/resnet/mod │
# │ eling_resnet.py:99 in forward                                                                    │
# │                                                                                                  │
# │    96 │   │   │   raise ValueError(                                                              │
# │    97 │   │   │   │   "Make sure that the channel dimension of the pixel values match with the   │
# │    98 │   │   │   )                                                                              │
# │ ❱  99 │   │   embedding = self.embedder(pixel_values)                                            │
# │   100 │   │   embedding = self.pooler(embedding)                                                 │
# │   101 │   │   return embedding                                                                   │
# │   102                                                                                            │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:150 │
# │ 1 in _call_impl                                                                                  │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/transformers/models/resnet/mod │
# │ eling_resnet.py:75 in forward                                                                    │
# │                                                                                                  │
# │    72 │                                                                                          │
# │    73 │   def forward(self, input: Tensor) -> Tensor:                                            │
# │    74 │   │   hidden_state = self.convolution(input)                                             │
# │ ❱  75 │   │   hidden_state = self.normalization(hidden_state)                                    │
# │    76 │   │   hidden_state = self.activation(hidden_state)                                       │
# │    77 │   │   return hidden_state                                                                │
# │    78                                                                                            │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:150 │
# │ 1 in _call_impl                                                                                  │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/torch/nn/modules/batchnorm.py: │
# │ 171 in forward                                                                                   │
# │                                                                                                  │
# │   168 │   │   passed when the update should occur (i.e. in training mode when they are tracked   │
# │   169 │   │   used for normalization (i.e. in eval mode when buffers are not None).              │
# │   170 │   │   """                                                                                │
# │ ❱ 171 │   │   return F.batch_norm(                                                               │
# │   172 │   │   │   input,                                                                         │
# │   173 │   │   │   # If buffers are not to be tracked, ensure that they won't be updated          │
# │   174 │   │   │   self.running_mean                                                              │
# │                                                                                                  │
# │ /Users/Jesse/Projects/devinterp/.venv/lib/python3.9/site-packages/torch/nn/functional.py:2450 in │
# │ batch_norm                                                                                       │
# │                                                                                                  │
# │   2447 │   if training:                                                                          │
# │   2448 │   │   _verify_batch_size(input.size())                                                  │
# │   2449 │                                                                                         │
# │ ❱ 2450 │   return torch.batch_norm(                                                              │
# │   2451 │   │   input, weight, bias, running_mean, running_var, training, momentum, eps, torch.b  │
# │   2452 │   )                                                                                     │
# │   2453                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
import matplotlib.pyplot as plt

trace = learning_coeff_stats["trace"]

for chain, df in trace.groupby("chain"):
    plt.plot(df.index, df["loss"], label=f"Chain {chain}")

plt.xlabel("Step")
plt.ylabel(r"$\hat\lambda$")
plt.title("Learning Coefficient Trace")
plt.legend()
plt.show()

# %% [markdown]
# To get a better understanding of the sampling methods, check out [`normal_crossing.ipynb`](/demos/normal_crossing.ipynb) and [`mnist.ipynb`](/demos/mnist.ipynb) where we compare SGLD to a variant known as Stochastic Gradient Nose-Hoover Thermostat (SGNHT), respectively in a simple toy landscape and on MNIST.

# %% [markdown]
# ## Project ideas
#
# What can you do with this? We wrote up [a bunch of ideas](https://devinterp.com/projects), most of which are focused on learning coefficient estimation, and we'd recommend starting there. There's a lot of low-hanging fruit.

# %% [markdown]
# ## Other Techniques
#
# There are plenty of other techniques that would fit naturally under the umbrella of "developmental interpretability." If you're interested in looking beyond learning coefficient estimation, here are some ideas (we welcome PRs to introduce these methods to the library!):
#
# - **Dimensionality reduction techniques**: Run PCA / t-SNE / UMAP / etc. over the weights / [tokens](https://transformer-circuits.pub/2022/in-context-learning-and-induction-heads/index.html#per-token-loss-intro) / activations over time. For larger models, you'll have to restrict your attention to a subset of the weights and activations for this to be tractable
# - **Progress measures**. If you have an understanding of some structure at the end of training, you can roll that understanding backwards to track how that structure develops over time.
# - **Probes**. Similarly, you can train a linear probe from activations onto features, then roll that probe back to previous checkpoints to measure how those features are learned.
# - **Gradients**. Just look at the gradients!
# - **Evals**. You can measure performance on a targeted benchmarks to track when the model learns the associated capabilities.
# - **Covariance estimators**. That's a secret for now. More coming soon!

# %% [markdown]
# # Systems
#
# ## Toy Landscapes
#
# ## MNIST
#
# ## ResNets
#
# ## Toy Models of Superposition
#
# ## Modular Arithmetic
#
# ## Deep Linear Networks
